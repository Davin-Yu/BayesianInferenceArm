# %% [markdown]
# # Bayesian Inference in Google Colab

# %% [markdown]
# ## Setup
# 1. Download the project from https://github.com/Davin-Yu/BayesianInferenceArm.
# 2. Unzip the file and upload to your Google Drive (recommended directory: MyDrive/Colab Notebooks/).
# 3. Run the following code blocks to link the project file.

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import sys
# Note you may need to change the path if you use a different folder for the project files
sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/BayesianInferenceArm-master')

# %% [markdown]
# ## An Hello-Agent Example

# %%
import batch_runs_parallel as b_runs

b_runs.start('batches_seqreachingtask')
#b_runs.start('batches_simplereachingtask')
# Out:
# Start time: 2026-06-10 07:15:04
# Base seed for this batch: 1781075704771
# Rebuilt combinations from allowed_pairs over base grid: 1 x 1 -> 1
# Generated 1 parameter combinations, with 1 reps each, for a total of 1 runs.
# Using 1 resampled repetitions and 1 identical repetitions per parameter combination.
# Max workers available: 1, using up to 1 parallel workers.
# Processing configurations:   0%|          | 0/1 [00:00<?, ?it/s]
# n_steps_max: 101
# Seqs of each 3 trials: 100%|██████████| 10/10 [00:27<00:00,  2.79s/it]
# WARNING: trajectory_alpha not available to save.
# WARNING: trajectory_beta not available to save.
# Animation progress: 100%|██████████| 757/757 [00:04<00:00, 177.25it/s]
# Total frames: 757
# Plotly animated plot created with frame_decimation set to 4
# 757 of 3030 steps animated
# Animation saved to: outputs/batches/seq_reaching_task_sim/plots/plotly_animation/prop_rad_sigma_0p015_prop_omega_sigma_0p06_rep_1_plotly_animation.html
# Processing configurations: 100%|██████████| 1/1 [00:37<00:00, 37.96s/it]
# All simulations completed in 38.03 seconds
# End time: 2026-06-10 07:15:42
# Configuration backup saved to: outputs/batches/seq_reaching_task_sim/seq_reaching_task_sim_config.json
# Batches backup saved to: outputs/batches/seq_reaching_task_sim/seq_reaching_task_sim_batches.json
# Average run time per configuration: 30.66 seconds
# Total configurations: 1

# %% [markdown]
# ## Understanding the Agent

# %% [markdown]
# ## Step-by-step Tutorial

# %% [markdown]
# #### Example 1

# %% [markdown]
# #### Example 2

# %% [markdown]
# #### Example 3

# %% [markdown]
# ## Building your own simulations
#
# Tasks (e.g., how to add blur?)
